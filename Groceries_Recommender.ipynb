# %% [markdown]
# <a href="https://colab.research.google.com/github/salarMokhtariL/Groceries-Recommender/blob/main/Groceries_Recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scalable Recommender System Development with PyTorch and Pandas for Enhanced Personalization
#
# >Realized on April
#
#
# **Team members:**
# *   **Helya Hosseini Nami**
# *   **Salar Mokhtari Laleh**
#
# # Introduction
# This notebook provides an implementation of a recommender system using PyTorch and demonstrates how to train and evaluate the model on a dataset of grocery transactions. The system utilizes item embeddings to represent the items in the dataset and computes their similarity to make recommendations.
#
# # Dataset
# The dataset used in this notebook is a list of grocery transactions. Each transaction consists of a list of items purchased by a customer. The dataset is available at the following URL:
#
# https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/groceries.csv
#
# # Implementation
# The implementation consists of the following steps:
#
# 1. Load the dataset using pandas and convert it to a list of lists.
# 2. Create a dictionary to map each item to a unique integer.
# 3. Convert the dataset to a list of lists of integers using the mapping dictionary.
# 4. Convert the dataset to a PyTorch tensor.
# 5. Define the model architecture using PyTorch.
# 6. Train the model on the dataset using PyTorch.
# 7. Compute the item embeddings and similarity matrix.
# 8. Generate recommendations for each item using the similarity matrix.

# %% [markdown]
# # Step 1: Load the dataset
# The first step is to load the dataset using pandas and convert it to a list of lists.

# %%
import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/groceries.csv',
                   header=None, delimiter='\t')

# %%
data.head(3)
# Out:
#                                                    0
# 0  citrus fruit,semi-finished bread,margarine,rea...
# 1                       tropical fruit,yogurt,coffee
# 2                                         whole milk

# %%
data.shape
# Out:
# (9835, 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9835 entries, 0 to 9834
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       9835 non-null   object
# dtypes: object(1)
# memory usage: 77.0+ KB

# %%
# Convert the data to a list of lists

data = data.values.tolist()

# %% [markdown]
# # Step 2: Create a mapping dictionary
# The second step is to create a dictionary to map each item to a unique integer.

# %%
item_to_int = {}
count = 0
for transaction in data:
    for item in transaction:
        if item not in item_to_int:
            item_to_int[item] = count
            count += 1

# %% [markdown]
# # Step 3: Convert the dataset to a list of lists of integers
# The third step is to convert the dataset to a list of lists of integers using the mapping dictionary.

# %%
data_int = []
for transaction in data:
    transaction_int = [item_to_int[item] for item in transaction]
    data_int.append(transaction_int)

# %% [markdown]
# # Step 4: Convert the dataset to a PyTorch tensor
# The fourth step is to convert the dataset to a PyTorch tensor.

# %%
import torch

data_tensor = torch.LongTensor(data_int)

# %% [markdown]
# # Step 5: Define the model architecture
# The fifth step is to define the model architecture using PyTorch. The model consists of an embedding layer, a fully connected layer, and an output layer.

# %%
import torch.nn as nn

class Recommender(nn.Module):
    def __init__(self, n_items, embedding_dim):
        super(Recommender, self).__init__()
        self.item_embedding = nn.Embedding(n_items, embedding_dim)
        self.fc1 = nn.Linear(embedding_dim, 128)
        self.fc2 = nn.Linear(128, n_items)
        self.activation = nn.ReLU()

    def forward(self, x):
        x = self.item_embedding(x)
        x = torch.mean(x, dim=1)
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# # Step 6: Train the model
# After setting the hyperparameters and initializing the model and optimizer, the next step is to train the model. The training process involves iterating over the data in batches and updating the model's parameters based on the loss calculated on the batch.

# %%
import torch.optim as optim

# %%
# Set the hyperparameters

n_items = len(item_to_int)
embedding_dim = 64
lr = 0.001
n_epochs = 10
batch_size = 256

# %%
# Initialize the model and optimizer

model = Recommender(n_items, embedding_dim)
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
# Define the loss function

criterion = nn.CrossEntropyLoss()

# %%
# Train the model

for epoch in range(n_epochs):
    for i in range(0, len(data_tensor), batch_size):
        batch = data_tensor[i:i+batch_size]
        targets = batch[:, -1]
        inputs = batch[:, :-1]
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}/{n_epochs} Loss: {loss.item()}')
# Out:
# Epoch 1/10 Loss: nan
# Epoch 2/10 Loss: nan
# Epoch 3/10 Loss: nan
# Epoch 4/10 Loss: nan
# Epoch 5/10 Loss: nan
# Epoch 6/10 Loss: nan
# Epoch 7/10 Loss: nan
# Epoch 8/10 Loss: nan
# Epoch 9/10 Loss: nan
# Epoch 10/10 Loss: nan

# %% [markdown]
# In each epoch, the data is split into batches of size `batch_size`, and for each batch, the model's parameters are updated based on the loss calculated on that batch. The `optimizer.zero_grad()` call is used to clear the gradients of all optimized tensors before running the backward pass, and the `optimizer.step()` call updates the model's parameters based on the computed gradients. The loss value for each epoch is printed to monitor the training progress.
#
# Note that the loss function used in this example is the cross-entropy loss, which is commonly used for multi-class classification problems. In this case, the task is to predict the next item in a sequence, given the previous items, so the target is a single integer representing the next item. The `nn.CrossEntropyLoss()` function expects the inputs to be a tensor of shape `(batch_size, n_classes)` and the targets to be a tensor of shape `(batch_size,)`, where each element is an integer representing the correct class label. In our case, the inputs are the output of the model and the targets are the last item in each batch.

# %% [markdown]
# # Step 7: Compute Item Similarities and Get Recommendations
#
# After training the model, we can compute the similarity between items and use it to generate recommendations for each item in the dataset.
#
# First, we will compute the similarity matrix between item embeddings using the dot product. The dot product measures the cosine similarity between two vectors, which is a common metric used for measuring similarity between embeddings.
#
# Then, for each item, we will get the top-k most similar items based on their cosine similarity score. Finally, we will convert the integer IDs back to the original item names and print the top-k recommendations for each item.
#
# Here's the code for computing item similarities and getting recommendations:

# %%
import numpy as np

# %%
# Get the item embeddings

item_embeddings = model.item_embedding.weight.data.cpu().numpy()

# %%
# Compute the similarity between items

similarity_matrix = np.dot(item_embeddings, item_embeddings.T)

# %%
# Get the top k recommendations for each item

k = 5
top_k = np.argsort(similarity_matrix, axis=1)[:, -(k+1):]

# %%
# Convert the integer ids back to item names

int_to_item = {v: k for k, v in item_to_int.items()}
top_k_items = np.vectorize(int_to_item.get)(top_k)

# %%
# Print the top k recommendations for each item

for i, item in enumerate(int_to_item.values()):
    print(f"Top {k} recommendations for {item}: {', '.join(top_k_items[i][::-1][1:])}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Top 5 recommendations for beef,citrus fruit,whole milk: UHT-milk,salt,soda,specialty chocolate,shopping bags, chicken,tropical fruit, beef,root vegetables,white bread,soda, citrus fruit,pip fruit,beverages,hard cheese,pet care,soda,fruit/vegetable juice,waffles, frankfurter,meat,root vegetables,onions,other vegetables,whole milk,yogurt,UHT-milk,rolls/buns,oil,mustard,canned fish,coffee,newspapers,shopping bags
# Top 5 recommendations for yogurt,UHT-milk,rolls/buns,candles: frankfurter,pip fruit,whole milk,soda, frankfurter,pork,whole milk,pastry,soda, hamburger meat,root vegetables,whole milk,whipped/sour cream,flour,chocolate marshmallow,newspapers, pork,citrus fruit,grapes,root vegetables,whole milk,ready soups,pot plants, ham,processed cheese,rolls/buns,white bread,fruit/vegetable juice,canned beer,long life bakery product,waffles,chocolate,specialty bar
# Top 5 recommendations for other vegetables,butter,yogurt,rolls/buns,pastry,margarine: frozen dessert,pastry,semi-finished bread,vinegar,coffee, turkey,citrus fruit,butter,whipped/sour cream,hard cheese,white bread, chicken,other vegetables,beverages,spices,hygiene articles, yogurt,soda,waffles, whole milk,bottled water,napkins
# Top 5 recommendations for sausage,citrus fruit,whole milk,yogurt,beverages,pasta,waffles,specialty chocolate: whole milk,margarine, oil,dish cleaner,newspapers, sausage,packaged fruit/vegetables,yogurt,rolls/buns,seasonal products, meat,pork,onions,salad dressing,domestic eggs,white bread,flour,salt,bottled beer, liver loaf,pork,citrus fruit,other vegetables,yogurt,misc. beverages
# Top 5 recommendations for sausage,citrus fruit,other vegetables,hard cheese,cream cheese ,frozen dessert,artif. sweetener,coffee,cling film/bags,newspapers: frankfurter,rolls/buns,ketchup,soda, soap,dishes, tropical fruit,pip fruit,root vegetables,whole milk,yogurt,beverages,domestic eggs,white bread,sweet spreads,soda, sausage,dessert,UHT-milk,soda,white wine, semi-finished bread
# Top 5 recommendations for finished products,soda,specialty chocolate: beef,root vegetables,frozen vegetables,frozen potato products,white bread,detergent, sausage,chicken,tropical fruit,onions,other vegetables,dessert,whipped/sour cream,UHT-milk,cream cheese ,pastry,bottled water,soda,waffles,chewing gum,shopping bags, liver loaf,pip fruit,root vegetables,frozen vegetables,salty snack, tropical fruit,root vegetables,other vegetables,domestic eggs,white bread,brown bread,canned vegetables,soda,fruit/vegetable juice,rum, margarine,candy
# Top 5 recommendations for other vegetables,whole milk,yogurt,specialty cheese,bottled water,misc. beverages,fruit/vegetable juice: whole milk,frozen dessert,salty snack,napkins, citrus fruit,cake bar,baby cosmetics,shopping bags, curd cheese,rolls/buns, packaged fruit/vegetables,dessert,mayonnaise,oil,soda,waffles,chocolate,flower (seeds),shopping bags, pip fruit,curd,soda,bottled beer,softener,hygiene articles
# Top 5 recommendations for pork,other vegetables,rolls/buns: tropical fruit,pip fruit,frozen meals,softener, pork,root vegetables,brown bread,pastry, whole milk,condensed milk, pork,root vegetables,whole milk,whipped/sour cream, pork,tropical fruit,pip fruit,other vegetables,whipped/sour cream,beverages,white bread,bottled beer,kitchen towels
# Top 5 recommendations for beef,root vegetables,other vegetables,whole milk,domestic eggs,hygiene articles: semi-finished bread, frankfurter,other vegetables,specialty cheese,chewing gum, frankfurter,grapes,yogurt,coffee,bottled water, sausage,other vegetables,whole milk,yogurt,soda, tropical fruit,soft cheese,rolls/buns,chocolate
# Top 5 recommendations for ham,citrus fruit,root vegetables,whipped/sour cream,canned beer,napkins: hamburger meat,canned beer, berries,root vegetables,herbs,other vegetables,whole milk,curd,cream cheese ,cereals,long life bakery product,waffles,shopping bags, chicken,soda,liquor,white wine,shopping bags, root vegetables,other vegetables,butter,hard cheese,margarine,mustard,pickled vegetables, meat,nuts/prunes,canned beer
# Top 5 recommendations for chicken,sugar,photo/film: sausage,yogurt,rolls/buns,soda, butter milk,domestic eggs,rolls/buns,soda,specialty chocolate, dessert,butter milk,brown bread,canned beer,shopping bags, ham,butter,yogurt,hard cheese,ice cream,domestic eggs,misc. beverages,fruit/vegetable juice, yogurt,bottled water,syrup,specialty bar
# Top 5 recommendations for pork,hamburger meat,pip fruit,herbs,other vegetables,whole milk,butter,sliced cheese,processed cheese,rolls/buns,pastry,roll products ,margarine: citrus fruit,whole milk,butter,yogurt,frozen vegetables,rolls/buns,baking powder,instant coffee,napkins,dishes,newspapers, beef,herbs,whole milk, cat food,coffee, cocoa drinks, liver loaf,citrus fruit,other vegetables,curd,salad dressing,semi-finished bread,abrasive cleaner
# Top 5 recommendations for chicken,other vegetables,bottled water,chewing gum,softener: sausage,pork,yogurt,spread cheese,cereals,canned vegetables,salty snack,cling film/bags,shopping bags, hamburger meat,other vegetables,rolls/buns, meat,chicken,pork,hamburger meat,citrus fruit,onions,other vegetables,yogurt,UHT-milk,spread cheese,domestic eggs,rolls/buns,margarine,bottled water,canned beer,female sanitary products,shopping bags, berries,other vegetables,whole milk,yogurt,whipped/sour cream,frozen vegetables,margarine,newspapers,flower (seeds), bottled water,canned beer
# Top 5 recommendations for sausage,ham,pip fruit,whole milk,butter milk,yogurt,hard cheese,spread cheese,rolls/buns,pastry,margarine,salty snack,shopping bags: curd,jam,shopping bags, other vegetables,whole milk,margarine,bottled beer, butter,bottled water,liquor,specialty bar,dishes,shopping bags, sausage,other vegetables,whole milk,yogurt,cream,frozen vegetables,frozen potato products,roll products ,rice,cat food,misc. beverages,fruit/vegetable juice,bottled beer,salty snack,specialty chocolate, pork,tropical fruit,processed cheese,specialty vegetables,bottled water,soda,bottled beer
# Top 5 recommendations for hard cheese,white bread,brown bread: sausage,beverages,brown bread,pastry, soda,bottled beer,specialty bar, butter,white wine, citrus fruit,tropical fruit,grapes,root vegetables,herbs,other vegetables,whole milk,frozen vegetables,rice,dog food,bottled water,misc. beverages,fruit/vegetable juice,napkins, pork,tropical fruit,root vegetables,whipped/sour cream,UHT-milk,frozen vegetables,roll products ,oil,bottled water,candy
# Top 5 recommendations for frankfurter,beef,citrus fruit,whole milk,rolls/buns,semi-finished bread,coffee,bottled beer: citrus fruit,tropical fruit,UHT-milk,bottled water,soda,misc. beverages,fruit/vegetable juice,napkins, other vegetables,whole milk,coffee, tropical fruit,other vegetables,whipped/sour cream,white bread, root vegetables,butter milk,cream cheese ,spread cheese, tropical fruit,root vegetables,whole milk,curd,dessert,butter milk,yogurt,sauces,bottled water,syrup,specialty chocolate,cleaner
# Top 5 recommendations for pastry,mustard,bottled beer: tropical fruit,oil,cat food, coffee,soda,chocolate marshmallow, fruit/vegetable juice,chocolate, other vegetables,whole milk,specialty chocolate,candy,newspapers, citrus fruit,tropical fruit,pip fruit,berries,bottled water,soda,red/blush wine
# Top 5 recommendations for tropical fruit,rolls/buns,pastry: sausage,meat,pip fruit,other vegetables,yogurt,rolls/buns,brown bread,bottled water,soda,fruit/vegetable juice,newspapers, sausage,root vegetables,packaged fruit/vegetables,yogurt,frozen potato products,brown bread,soda,candy, dessert,misc. beverages,fruit/vegetable juice,popcorn,shopping bags, sausage,citrus fruit,other vegetables,dessert,yogurt,whipped/sour cream,hard cheese,curd cheese,white bread,semi-finished bread,cat food,bottled water,seasonal products,softener,flower soil/fertilizer,flower (seeds), whipped/sour cream,pastry,canned fish,soda,waffles,dish cleaner,napkins
# Top 5 recommendations for frozen meals,rolls/buns,bottled beer: pork,other vegetables,whole milk,cream cheese ,frozen fish,rolls/buns,pastry, bottled water,canned beer, photo/film, ham,root vegetables,onions,other vegetables,whole milk,whipped/sour cream,soft cheese,sliced cheese,hard cheese,cream cheese ,specialty cheese,domestic eggs,salt,canned fish,napkins, root vegetables,butter,curd,pastry,chocolate,kitchen towels
# Top 5 recommendations for pork,sugar,newspapers: sausage,liver loaf,specialty cheese,soda, root vegetables,whole milk,detergent, softener,newspapers, rolls/buns,soda,snack products,newspapers, frankfurter,meat,pork,beef,berries,other vegetables,whole milk,domestic eggs,Instant food products,coffee,skin care
# Top 5 recommendations for hamburger meat,pip fruit,whole milk,hard cheese,chocolate: citrus fruit,whole milk,yogurt,spread cheese,brown bread,bottled beer,white wine,long life bakery product,flower (seeds), citrus fruit,other vegetables,canned fish,bottled water, rolls/buns,canned fish,canned beer, hamburger meat,tropical fruit,root vegetables,whole milk,frozen meals,rolls/buns,pasta,waffles, beef,whole milk,pastry,semi-finished bread,specialty chocolate,chocolate marshmallow
# Top 5 recommendations for other vegetables,pastry,candy,napkins: chicken,whole milk,rolls/buns,flour,salt,vinegar,sugar, yogurt,organic products,shopping bags, citrus fruit,other vegetables,packaged fruit/vegetables,yogurt,margarine,sugar,artif. sweetener,baking powder,candles, misc. beverages,waffles,candy, root vegetables,herbs,other vegetables,candy,seasonal products,shopping bags
# Top 5 recommendations for hamburger meat,hard cheese,frozen vegetables,soda: frankfurter,citrus fruit,canned vegetables,coffee, frankfurter,meat,pork,root vegetables,onions,whole milk,beverages,mayonnaise,soda,chocolate, hamburger meat,whole milk,yogurt,soft cheese,frozen potato products,pasta,canned vegetables,fruit/vegetable juice,popcorn, pork,onions,other vegetables,butter milk, tropical fruit,pip fruit,grapes
# Top 5 recommendations for berries,root vegetables,whole milk,curd,frozen fish,domestic eggs,rolls/buns: UHT-milk,bottled beer,liquor (appetizer),dishes, sausage,rolls/buns,shopping bags, beverages,sauces,sweet spreads,pot plants, pip fruit,root vegetables,other vegetables,whole milk,yogurt,rolls/buns, pork,rolls/buns,pastry,napkins,newspapers
# Top 5 recommendations for sausage,yogurt,rolls/buns,soda: pip fruit,misc. beverages, citrus fruit,tropical fruit,pip fruit,grapes,berries,root vegetables,other vegetables,beverages,Instant food products,long life bakery product, frankfurter,other vegetables,frozen vegetables,waffles,cake bar, citrus fruit,specialty bar, hamburger meat,tropical fruit
# Top 5 recommendations for dessert,rolls/buns,sugar,bottled water: sausage,citrus fruit,tropical fruit,whole milk,bottled water,specialty bar,detergent,newspapers, sausage,onions,rolls/buns,soda,brandy,white wine,chewing gum,napkins,shopping bags, whole milk,dessert,yogurt,sliced cheese,rolls/buns,soda,seasonal products, frankfurter,pip fruit,root vegetables,other vegetables,whole milk,soft cheese,cream cheese ,frozen vegetables,salt,specialty fat,sugar,jam,canned fish,coffee,fruit/vegetable juice,long life bakery product,waffles,chocolate,shopping bags, ice cream,salty snack,waffles
# Top 5 recommendations for pip fruit,whole milk,domestic eggs: pork,frozen vegetables, frozen fish,sugar,cake bar,chocolate marshmallow,candy, pork,root vegetables,other vegetables, whole milk,mustard, citrus fruit,root vegetables,other vegetables,coffee,liquor,chocolate,candy,seasonal products,flower (seeds),shopping bags
# Top 5 recommendations for liver loaf,beef,onions,specialty chocolate,napkins,shopping bags: beef,frozen fish,rolls/buns,margarine, beef,citrus fruit,root vegetables,yogurt,whipped/sour cream,brown bread,napkins,newspapers, beef,hamburger meat,other vegetables,sliced cheese, chocolate, root vegetables,whole milk,soda,detergent,softener,dish cleaner,photo/film
# Top 5 recommendations for root vegetables,whole milk,rolls/buns,specialty chocolate: bottled beer,nut snack, frozen vegetables,specialty chocolate, ham,UHT-milk, sausage,bottled water,red/blush wine, chocolate,pot plants,shopping bags
# Top 5 recommendations for root vegetables,yogurt,pastry: butter,sliced cheese,brown bread, sausage,root vegetables,other vegetables,whole milk,curd,yogurt,hard cheese,white bread, tropical fruit,onions,whole milk,butter,dishes, frankfurter,whole milk,rolls/buns,salt, pork,pip fruit,curd,roll products ,margarine,soups,coffee,napkins,newspapers
# Top 5 recommendations for other vegetables,rolls/buns,soda: root vegetables,other vegetables,whole milk,bottled water,bottled beer, hard cheese,salt,canned vegetables, sausage,beverages,rolls/buns, beef,whole milk,frozen vegetables,brown bread,pastry,coffee, nuts/prunes,rolls/buns
# Top 5 recommendations for chicken,pip fruit,whole milk,pastry,coffee: meat,curd,white bread, frankfurter,grapes,yogurt,cream cheese ,frozen potato products,rolls/buns,meat spreads,bottled water,soda,chewing gum, citrus fruit,pip fruit,root vegetables,whole milk,coffee,popcorn,chewing gum,detergent,newspapers,shopping bags, sausage,ham,pip fruit,whole milk,curd,butter milk,yogurt,sliced cheese, pip fruit,butter,frozen meals,pasta,bottled water
# Top 5 recommendations for butter milk,canned fish: meat,dessert,UHT-milk,rice,specialty bar,napkins,candles, pastry,candles, beverages,pastry,bottled water, butter,hard cheese,white bread,chocolate,candy, hamburger meat,brown bread,semi-finished bread
# Top 5 recommendations for butter milk,soft cheese,rolls/buns: beef,other vegetables,butter milk,soups,sparkling wine, white bread,misc. beverages,long life bakery product, meat,other vegetables,whole milk,hard cheese,fruit/vegetable juice,long life bakery product, other vegetables,whipped/sour cream,condensed milk,salt, tropical fruit,yogurt,condensed milk,brown bread,soda,bottled beer
# Top 5 recommendations for onions,other vegetables,specialty cheese: sausage,chicken,beef,citrus fruit,tropical fruit,root vegetables,onions,herbs,other vegetables,whole milk,butter,curd,yogurt,frozen meals,domestic eggs, beverages,frozen vegetables,coffee,soda,fruit/vegetable juice,cling film/bags, pip fruit,root vegetables,other vegetables,whole milk,chewing gum,kitchen towels, semi-finished bread,long life bakery product,waffles,detergent,newspapers,shopping bags, tropical fruit,curd,newspapers
# Top 5 recommendations for ham,hamburger meat,other vegetables,whole milk,curd,mayonnaise,domestic eggs,rolls/buns,margarine: other vegetables,whole milk,soda,chocolate, other vegetables,whole milk,curd,cream cheese ,frozen vegetables,roll products ,sugar,soda,bottled beer,salty snack,popcorn, other vegetables,whole milk,yogurt,ice cream,flour,margarine,baking powder,pudding powder, frankfurter,meat,pork,grapes,root vegetables,whipped/sour cream,domestic eggs, citrus fruit,curd,yogurt,sliced cheese,rolls/buns,oil,bottled water
# Top 5 recommendations for chicken,other vegetables,whole milk,yogurt,frozen vegetables,coffee,bottled beer,red/blush wine: whole milk,rolls/buns,pastry, frankfurter,sausage,liver loaf,ham,chicken,beef,citrus fruit,tropical fruit,root vegetables,other vegetables,whole milk,butter,curd,yogurt,whipped/sour cream,beverages,soft cheese,hard cheese,cream cheese ,mayonnaise,domestic eggs,rolls/buns,roll products ,flour,pasta,margarine,specialty fat,sugar,soups,skin care,hygiene articles,candles, tropical fruit,grapes,other vegetables,whole milk,brown bread,pastry,fruit/vegetable juice,long life bakery product,pot plants, root vegetables,packaged fruit/vegetables,rolls/buns,sugar,liquor, ham,whole milk,hard cheese,cat food
# Top 5 recommendations for whole milk,curd,dessert,shopping bags: chicken,bottled water,liquor (appetizer), frankfurter,pork,citrus fruit,whole milk,whipped/sour cream,rolls/buns,oil,sugar,soups,bottled water,bottled beer, frankfurter,frozen potato products,rolls/buns,specialty fat, citrus fruit,other vegetables,canned fish,bottled water, chocolate,candy
# Top 5 recommendations for frankfurter,hamburger meat,tropical fruit,root vegetables,domestic eggs,Instant food products,detergent: baking powder,coffee,canned beer, sausage,yogurt, pip fruit,bottled water,white wine,newspapers, pork,root vegetables,other vegetables,whole milk,cream cheese ,coffee,bottled water,bottled beer, whipped/sour cream,cream cheese
# Top 5 recommendations for citrus fruit,pip fruit,whole milk,curd,whipped/sour cream,bottled water,bottled beer,specialty chocolate,shopping bags: meat,pip fruit,whole milk,soda,newspapers, citrus fruit,yogurt,newspapers, sausage,yogurt,white wine, whole milk,frozen meals,rolls/buns, chicken,UHT-milk,frozen vegetables,ice cream,pickled vegetables,bottled beer,newspapers,shopping bags
# Top 5 recommendations for tropical fruit,whole milk,cat food,popcorn,specialty bar: pip fruit,semi-finished bread,soups, hamburger meat,other vegetables,sauces,soda,salty snack,newspapers, sausage,root vegetables,soda,bottled beer,salty snack,popcorn, root vegetables,sliced cheese, brown bread,dog food,canned beer
# Top 5 recommendations for citrus fruit,other vegetables,butter,brown bread,baking powder,bottled water,soda: berries,whole milk,hard cheese,processed cheese,domestic eggs,rolls/buns,white bread,margarine,sugar,waffles, frankfurter,pork,tropical fruit,pip fruit,other vegetables,whole milk,dessert,whipped/sour cream,cream cheese ,frozen meals,cat food,salty snack,cake bar,chewing gum,specialty bar,seasonal products, sausage,ham,citrus fruit,grapes,berries,butter milk,frozen meals,domestic eggs,cat food,coffee,bottled water,soda,fruit/vegetable juice,waffles,hygiene articles, other vegetables,canned beer,shopping bags, root vegetables,soda,liquor
# Top 5 recommendations for citrus fruit,rolls/buns,pastry,soda,pot plants,shopping bags: pip fruit,white bread,coffee,soda,fruit/vegetable juice,bottled beer,sparkling wine, sausage,sliced cheese,pickled vegetables, citrus fruit,rolls/buns,specialty bar, citrus fruit,tropical fruit,pip fruit,other vegetables,zwieback,shopping bags, pork,beef
# Top 5 recommendations for chicken,onions,other vegetables,whole milk,frozen fish,brown bread,soda,white wine: pork,yogurt,UHT-milk,salty snack, ham,whole milk,yogurt,soda,red/blush wine, other vegetables,butter milk,yogurt,fruit/vegetable juice, ham,chicken,other vegetables,processed cheese,white bread,detergent, sausage,meat,butter,domestic eggs,cat food
# Top 5 recommendations for sugar,bottled water,white wine: sausage,citrus fruit,whole milk,UHT-milk,specialty cheese,frozen vegetables,tea,bottled water,fruit/vegetable juice, other vegetables,whole milk,rolls/buns,sugar, meat,dessert,UHT-milk,rice,specialty bar,napkins,candles, sliced cheese,frozen meals,margarine,red/blush wine, meat,butter,pastry,soda
# Top 5 recommendations for pork,tropical fruit,whole milk,curd,frozen meals,domestic eggs,margarine,pickled vegetables,soda,bottled beer,pot plants: rolls/buns,soda,canned beer,waffles,shopping bags, whole milk,frozen vegetables,specialty chocolate, other vegetables,whole milk,frozen potato products, sausage,other vegetables,newspapers,shopping bags, ham,tropical fruit,pip fruit,root vegetables,domestic eggs,napkins,newspapers
# Top 5 recommendations for rolls/buns,soda,waffles,chewing gum: pip fruit,herbs,other vegetables,whole milk,coffee,female sanitary products,hygiene articles,shopping bags, soda,long life bakery product,shopping bags, frozen chicken, frankfurter,tropical fruit,root vegetables,butter milk,beverages,brown bread,fruit/vegetable juice, butter,cleaner
# Top 5 recommendations for whole milk,frozen vegetables,rolls/buns,pastry,kitchen towels,newspapers: rolls/buns,bottled water,soda, frankfurter,soda, herbs,yogurt, sausage,chicken,other vegetables,whole milk,yogurt,rolls/buns,soda,hygiene articles,napkins,shopping bags, meat,whole milk,cream cheese ,brown bread,chocolate,newspapers
# Top 5 recommendations for rolls/buns,brown bread,fruit/vegetable juice,newspapers: pip fruit,root vegetables,whole milk,ice cream,bottled beer,detergent, other vegetables,rolls/buns,bottled water,skin care, tropical fruit,ice cream,frozen dessert,candy, hamburger meat,hard cheese,frozen meals,pasta,dog food,salty snack,shopping bags, pip fruit,whole milk,soda
# Top 5 recommendations for mayonnaise,rolls/buns: other vegetables,whole milk,coffee,soda,canned beer, other vegetables,whole milk,yogurt,spices, whole milk,whipped/sour cream,rolls/buns,pot plants, pip fruit,processed cheese,bottled water, whole milk,brown bread,flower (seeds)
# Top 5 recommendations for pork,frozen vegetables,pastry,misc. beverages: root vegetables,onions,dessert,mayonnaise,brown bread,salt,canned fish,bottled water,fruit/vegetable juice,bottled beer,popcorn, tropical fruit,grapes,other vegetables,curd,beverages,pastry,nut snack, other vegetables,chocolate marshmallow, domestic eggs,brown bread,photo/film, frankfurter,bottled water,misc. beverages,bottled beer,sparkling wine
# Top 5 recommendations for citrus fruit,other vegetables,whole milk,flour: pork,root vegetables,other vegetables,whole milk,cream cheese ,coffee,bottled water,bottled beer, finished products,other vegetables,butter,cream cheese ,processed cheese,domestic eggs,rolls/buns,pastry,long life bakery product,candy, sausage,frozen meals,shopping bags, ham,frozen meals,rolls/buns,canned fish,coffee,instant coffee, tropical fruit,butter milk,brown bread,flour
# Top 5 recommendations for soda,chewing gum,newspapers,photo/film: tropical fruit,root vegetables,butter,pasta,soda,napkins, sausage,frozen meals,shopping bags, citrus fruit,other vegetables,soft cheese,rolls/buns,pastry,canned beer,newspapers, sauces,red/blush wine,dish cleaner, liver loaf,dessert,domestic eggs,soda,cleaner,shopping bags
# Top 5 recommendations for bottled beer,liquor (appetizer),dishes: citrus fruit,grapes,whole milk,pastry,canned fruit,canned fish,chocolate,specialty bar,hygiene articles,napkins,shopping bags, beef,chocolate, pip fruit,sliced cheese,pastry,white wine,light bulbs,newspapers, dessert,cream cheese ,mayonnaise,domestic eggs,pastry,canned fish,chocolate,cleaner,female sanitary products, frankfurter,sausage,meat,whole milk,beverages,hard cheese,fruit/vegetable juice,bottled beer,sparkling wine,specialty chocolate,napkins
# Top 5 recommendations for sausage,pork,beef,hamburger meat,grapes,root vegetables,other vegetables,dessert,rolls/buns,dog food,napkins: whole milk,rolls/buns,detergent, chicken,tropical fruit,root vegetables,other vegetables,beverages,coffee,bottled beer,liquor, herbs,other vegetables,sliced cheese,cream cheese ,salt,oil,margarine,fruit/vegetable juice,bottled beer,chewing gum,hygiene articles, yogurt,misc. beverages, frankfurter,packaged fruit/vegetables,soft cheese,soda
# Top 5 recommendations for sausage,bottled beer,dish cleaner: other vegetables,butter,soda,bottled beer,liquor,rum,chocolate marshmallow,hygiene articles,newspapers, UHT-milk,specialty bar, tropical fruit,berries,other vegetables,whole milk,yogurt,whipped/sour cream,frozen vegetables,coffee,bottled water,soda,salty snack,long life bakery product,specialty bar, ham,tropical fruit,pip fruit,other vegetables,whole milk,processed cheese,frozen vegetables,brown bread,soda,shopping bags, oil,dish cleaner,newspapers
# Top 5 recommendations for tropical fruit,grapes,UHT-milk,pickled vegetables,jam,coffee,salty snack: other vegetables,whole milk,yogurt,beverages,hard cheese,fruit/vegetable juice, frankfurter,sausage,butter,whipped/sour cream,rolls/buns,margarine,spices, whole milk,whipped/sour cream,rolls/buns,pot plants, pork,beef,whole milk,yogurt,sliced cheese,oil, tropical fruit,frozen meals,frozen fish,salty snack,long life bakery product,chocolate,specialty chocolate
# Top 5 recommendations for frankfurter,pork,root vegetables,whole milk,yogurt,frozen fish,soda: other vegetables,ice cream, liver loaf,pip fruit,grapes,other vegetables, frozen vegetables,rolls/buns,pastry, ham,beef,citrus fruit,newspapers, sliced cheese,rolls/buns
# Top 5 recommendations for sausage,citrus fruit,berries,other vegetables,hard cheese,rolls/buns,bottled water: sausage,chicken,citrus fruit,pip fruit,root vegetables,other vegetables,whole milk,yogurt,whipped/sour cream,domestic eggs,white bread,soda,shopping bags, chicken,root vegetables,yogurt,cream cheese ,napkins, whole milk,butter,cat food, chicken,beef,whole milk,bottled water,newspapers, hamburger meat,photo/film
# Top 5 recommendations for sausage,butter milk,rolls/buns,bottled water,soda,canned beer,shopping bags: pork,tropical fruit,pip fruit,processed cheese,spread cheese,curd cheese,bottled beer, tropical fruit,grapes,whole milk,pastry,dog food,soda,waffles,specialty bar,cleaner,shopping bags, organic sausage,tropical fruit,packaged fruit/vegetables,whole milk,curd,yogurt,soft cheese,curd cheese,frozen vegetables,domestic eggs,rolls/buns,pastry,margarine,bottled water,cooking chocolate,hygiene articles,shopping bags, chicken,other vegetables,frozen vegetables,canned beer,shopping bags, beef,root vegetables,other vegetables,whole milk,curd,cream,domestic eggs,soda,fruit/vegetable juice
# Top 5 recommendations for root vegetables,herbs,whole milk,butter milk,cream cheese ,waffles,napkins,newspapers: pip fruit,whole milk,newspapers, yogurt,rolls/buns,instant coffee,soda,canned beer,waffles, whole milk,baking powder,bottled water,soda,cooking chocolate,candles, cat food,bottled water,hygiene articles, whipped/sour cream,napkins
# Top 5 recommendations for sausage,rolls/buns,brandy: dessert,fruit/vegetable juice,nut snack,specialty bar, pork,tropical fruit,pip fruit,other vegetables,whipped/sour cream,beverages,white bread,bottled beer,kitchen towels, specialty chocolate, other vegetables,fruit/vegetable juice,chewing gum, pork,canned beer,seasonal products
# Top 5 recommendations for root vegetables,other vegetables,whole milk,butter,mustard,bottled water,flower (seeds): butter,yogurt, cream cheese ,brown bread, frankfurter,rolls/buns,ketchup,soda, honey,flower (seeds), tropical fruit,condensed milk,dog food,bottled water,fruit/vegetable juice,specialty chocolate
# Top 5 recommendations for tropical fruit,candy: processed cheese,rolls/buns,detergent,dish cleaner,flower soil/fertilizer, hamburger meat,citrus fruit,tropical fruit,pip fruit,whole milk,yogurt,frozen meals,domestic eggs,brown bread,pasta,sugar,Instant food products,canned fish,soda,salty snack,popcorn,chocolate,dish cleaner,shopping bags, hard cheese, citrus fruit,tropical fruit,rolls/buns,oil,mustard,soups,sweet spreads,soda,syrup,canned beer,waffles,chocolate,specialty bar,dish cleaner,baby cosmetics,cookware, whole milk,butter milk,specialty bar
# Top 5 recommendations for hamburger meat,fruit/vegetable juice,canned beer,white wine: UHT-milk,bottled water,chewing gum,cling film/bags,shopping bags, frankfurter,tropical fruit,pip fruit,whole milk,curd,pastry,flour,margarine,sugar,organic products, citrus fruit,tropical fruit,whole milk,yogurt,soft cheese,cat food,bottled water,chocolate,specialty chocolate, white bread,soda,bottled beer, root vegetables,other vegetables,yogurt,rolls/buns,flour
# Top 5 recommendations for meat,whole milk,yogurt,soda,male cosmetics: tropical fruit,soda,rum, frozen vegetables,brown bread, sausage,chicken,beef,root vegetables,other vegetables,curd,yogurt,cream cheese ,ice cream,newspapers, whole milk,rolls/buns,detergent, tropical fruit,pastry,flour,rum
# Top 5 recommendations for frankfurter,white bread,margarine,shopping bags: whole milk,curd,frozen dessert,rolls/buns,long life bakery product, yogurt,liquor (appetizer),nut snack,long life bakery product,hygiene articles,shopping bags, pasta, meat,pip fruit,root vegetables,whole milk,frozen vegetables, frankfurter,UHT-milk,hard cheese,spread cheese,brown bread,pastry,bottled water,seasonal products,shopping bags
# Top 5 recommendations for whole milk,fruit/vegetable juice: citrus fruit,root vegetables,whole milk,curd, citrus fruit,herbs,butter,domestic eggs,oil,bottled water,bottled beer, frankfurter,citrus fruit,onions,other vegetables,canned beer,chocolate, pork,citrus fruit,other vegetables,dessert,white bread,kitchen towels,candles,newspapers, finished products,fruit/vegetable juice,white wine,chocolate,pot plants
# Top 5 recommendations for pastry,newspapers: root vegetables,herbs,whole milk, sausage,butter,hard cheese,domestic eggs, spread cheese,rolls/buns,white bread,pet care,fruit/vegetable juice,newspapers, frankfurter,beef,herbs,whole milk,rolls/buns, sausage,whole milk,yogurt,brown bread,cereals,bottled water,soda
# Top 5 recommendations for canned beer,salty snack: pip fruit,bottled water,candy, frankfurter,ham,meat,pip fruit,berries,UHT-milk,soft cheese,sliced cheese,cream cheese ,frozen vegetables,frozen fish,white bread,brown bread,sugar,sauces,sweet spreads,canned fish,pet care,fruit/vegetable juice,specialty bar,kitchen towels, berries,whole milk,whipped/sour cream,pickled vegetables,detergent,newspapers, brown bread,bottled water,bottled beer, chicken,pip fruit,soda
# Top 5 recommendations for ham,citrus fruit,tropical fruit,whole milk,yogurt,whipped/sour cream,soda: semi-finished bread, root vegetables,other vegetables,whole milk,rolls/buns,bottled water,dishes,newspapers, sausage,meat,citrus fruit,yogurt,ice cream,rolls/buns,brown bread,pickled vegetables,jam,liquor,newspapers, pork,onions,rolls/buns,margarine,canned vegetables,soda,salty snack,house keeping products, tropical fruit,curd
# Top 5 recommendations for pork,root vegetables,onions,other vegetables,margarine,sugar,spices: sausage,root vegetables,whole milk,whipped/sour cream,rolls/buns,mustard, root vegetables,whole milk,butter,yogurt,whipped/sour cream,soft cheese,cream cheese ,domestic eggs,brown bread,jam,misc. beverages,fruit/vegetable juice,napkins,pot plants, tropical fruit,pip fruit,whole milk,chewing gum,chocolate, citrus fruit,tropical fruit,pip fruit,rolls/buns,soda,canned beer, citrus fruit,tropical fruit,pip fruit,yogurt,pastry,margarine,cat food,pet care,bottled water,chocolate,specialty bar,dental care,napkins
# Top 5 recommendations for citrus fruit,pip fruit,root vegetables,onions,herbs,other vegetables,whole milk,butter,processed cheese,frozen vegetables,bottled water,red/blush wine,long life bakery product,chocolate,rubbing alcohol,hygiene articles,napkins: frankfurter,berries,whole milk,rice,coffee,cling film/bags, UHT-milk,specialty bar, whole milk,pastry,bottled water,hygiene articles, chicken,citrus fruit,onions,other vegetables,whole milk,frozen fish,roll products ,flour,sugar,pickled vegetables, citrus fruit,yogurt,fruit/vegetable juice,napkins
# Top 5 recommendations for meat,finished products,white bread,long life bakery product,shopping bags: chicken,hamburger meat,grapes,other vegetables,whipped/sour cream,brown bread,canned beer,sparkling wine,flower (seeds), beverages,rolls/buns,soda,misc. beverages,liqueur,cake bar, whipped/sour cream,salty snack, tropical fruit,yogurt,beverages,rolls/buns,waffles,specialty chocolate,shopping bags, whole milk,domestic eggs,brown bread,photo/film
# Top 5 recommendations for soda,fruit/vegetable juice,specialty bar: sausage,tropical fruit,root vegetables,other vegetables,cream cheese ,pickled vegetables,candles, bottled water,canned beer,candy, beef,root vegetables,onions,herbs,whole milk,curd cheese,rolls/buns,oil,jam,bottled water,waffles, whipped/sour cream,beverages,liquor (appetizer), pip fruit,bottled water,candy
# Top 5 recommendations for yogurt,cream cheese ,rolls/buns,chocolate: tropical fruit,root vegetables,whole milk,frozen vegetables,domestic eggs,brown bread,semi-finished bread,canned beer, citrus fruit,bottled water,red/blush wine,photo/film, pork,citrus fruit,whole milk,curd,yogurt,bottled beer,dishes, sausage,frozen vegetables,domestic eggs,soda,fruit/vegetable juice,napkins,pot plants, root vegetables,other vegetables,yogurt,cream cheese ,rolls/buns
# Top 5 recommendations for whipped/sour cream,domestic eggs,margarine: pip fruit,berries,root vegetables,yogurt,soft cheese,hard cheese,frozen meals,frozen fish,frozen dessert,white bread,pastry,pasta,cereals,soda,long life bakery product,cake bar,detergent, pip fruit,other vegetables,margarine,photo/film, ham,butter,yogurt,hard cheese,ice cream,domestic eggs,misc. beverages,fruit/vegetable juice, other vegetables,rolls/buns, pastry,canned beer,salty snack,long life bakery product,specialty chocolate,candy,candles
# Top 5 recommendations for sausage,other vegetables,yogurt,bottled water,soda,canned beer,shopping bags: citrus fruit,root vegetables,frozen vegetables,chewing gum, beef,citrus fruit,root vegetables,whole milk,rolls/buns,pastry,coffee,seasonal products, pork,tropical fruit,pip fruit,nuts/prunes,other vegetables,frozen meals,margarine,newspapers, meat,hamburger meat,Instant food products,soda, other vegetables,frozen fish,pickled vegetables,dog food,salty snack,shopping bags
# Top 5 recommendations for root vegetables,other vegetables,photo/film: whole milk,cream cheese ,soda,fruit/vegetable juice, tropical fruit,other vegetables,whole milk,fruit/vegetable juice,long life bakery product,shopping bags, other vegetables,whole milk,processed cheese,white bread,soda,newspapers, citrus fruit,whole milk,yogurt,whipped/sour cream,cat food,specialty chocolate,female sanitary products, sausage,other vegetables
# Top 5 recommendations for rolls/buns,coffee,red/blush wine,chewing gum: tropical fruit,coffee,candy,soap,shopping bags, tropical fruit,curd, whole milk,butter,margarine,specialty fat,specialty chocolate,candles,flower (seeds), turkey,grapes,other vegetables,hard cheese,frozen vegetables,rolls/buns,misc. beverages,newspapers, chicken,red/blush wine
# Top 5 recommendations for frankfurter,sausage,pip fruit,other vegetables,rolls/buns,sweet spreads,chocolate: root vegetables,butter,margarine, other vegetables,butter milk,yogurt,fruit/vegetable juice, root vegetables,other vegetables,butter,hard cheese,margarine,mustard,pickled vegetables, beverages,misc. beverages, pork,onions,shopping bags
# Top 5 recommendations for sausage,yogurt,rolls/buns,pastry,dog food,soda: frankfurter,pork,pip fruit,root vegetables,other vegetables,whole milk,butter milk,yogurt,cream cheese ,rolls/buns,brown bread,soda, other vegetables,fruit/vegetable juice,chewing gum, pork,beef,butter,whipped/sour cream,frozen meals,frozen fish,rolls/buns,pastry,canned fish,cat food,waffles,chocolate,shopping bags, dessert,spread cheese,rolls/buns,brown bread,soda,canned beer,newspapers, frankfurter,tropical fruit,onions,dessert,ice cream,dishes,candles
# Top 5 recommendations for frankfurter,rolls/buns,brown bread,shopping bags: chicken,beef,citrus fruit,whole milk,cream cheese ,domestic eggs,rolls/buns,canned beer,napkins,shopping bags, soda,seasonal products, citrus fruit,root vegetables,other vegetables,coffee,liquor,chocolate,candy,seasonal products,flower (seeds),shopping bags, sausage,butter milk,rolls/buns, grapes,UHT-milk
# Top 5 recommendations for ham,pork,other vegetables,whole milk,frozen vegetables,rolls/buns,rum: frankfurter,root vegetables,rolls/buns,pastry,mustard,bottled beer,shopping bags, root vegetables,other vegetables,whole milk,rolls/buns,pastry,bottled water,soda,waffles,cake bar, whole milk,butter,sugar,bottled beer, other vegetables,frozen meals,pasta,canned fish,coffee, ice cream,oil,bottled beer
# Top 5 recommendations for bottled beer,newspapers: canned beer,salty snack,shopping bags, tropical fruit,frozen vegetables, yogurt,frozen fish,rolls/buns, UHT-milk,domestic eggs,sugar,fruit/vegetable juice,newspapers, mayonnaise,rolls/buns
# Top 5 recommendations for chicken,citrus fruit,tropical fruit,other vegetables,whole milk,whipped/sour cream,rolls/buns,pastry,flour,specialty chocolate: whipped/sour cream,domestic eggs,candles, beef,root vegetables,whole milk,butter,yogurt,soda,abrasive cleaner,newspapers, chicken,beef,tropical fruit,berries,frozen vegetables,zwieback,dishes, whole milk,rolls/buns,white bread,soap, whole milk,yogurt,cream cheese ,oil,pickled vegetables,cat food,misc. beverages,long life bakery product,chocolate,specialty bar,dishes
# Top 5 recommendations for specialty cheese,hygiene articles,newspapers,shopping bags: root vegetables,soda,liquor, whole milk,dessert,yogurt,white bread, pastry,oil, root vegetables,other vegetables,whole milk,soups,bottled beer, pork,hamburger meat,tropical fruit,whole milk,margarine,canned vegetables,shopping bags
# Top 5 recommendations for frankfurter,sausage,citrus fruit,root vegetables,other vegetables,whole milk,yogurt,whipped/sour cream,frozen vegetables,white bread,brown bread,pasta,vinegar,soda,salty snack,detergent: soda,seasonal products, Instant food products,long life bakery product,specialty chocolate,cling film/bags,house keeping products, root vegetables,other vegetables,mayonnaise,soda,chocolate,specialty chocolate, meat,chicken,root vegetables,other vegetables,whole milk,whipped/sour cream,rolls/buns,abrasive cleaner,cleaner,napkins,house keeping products, root vegetables,other vegetables,yogurt,cream cheese ,rolls/buns
# Top 5 recommendations for pip fruit,bottled beer: grapes,specialty cheese,pasta,coffee,bottled water,soda,canned beer,brandy,white wine, root vegetables,butter milk,cream cheese ,spread cheese, frankfurter,meat,beef,citrus fruit,berries,root vegetables,packaged fruit/vegetables,whole milk,whipped/sour cream,frozen vegetables,rolls/buns,canned fruit,house keeping products,flower (seeds),shopping bags, whole milk,frozen vegetables,bottled water, grapes,brown bread
# Top 5 recommendations for beef,root vegetables,other vegetables,whole milk,dessert,yogurt,rolls/buns,margarine,jam,soda,liquor (appetizer),waffles,chocolate marshmallow,candy,bathroom cleaner,light bulbs: citrus fruit,root vegetables,other vegetables,whole milk,curd,yogurt,whipped/sour cream,hard cheese,cream cheese ,domestic eggs,flour,rice,oil,margarine,sugar, other vegetables,whole milk,soda,chocolate, sugar,bottled water,soda,fruit/vegetable juice,salty snack,popcorn, pork,whole milk,soda,canned beer,salty snack,chewing gum,candy, root vegetables,spices,kitchen towels
# Top 5 recommendations for rolls/buns,pastry: frankfurter,whipped/sour cream,sugar,fruit/vegetable juice,napkins,newspapers, meat,yogurt,napkins, pork,margarine,dishes, sausage,citrus fruit,root vegetables,other vegetables,rolls/buns,soda,fruit/vegetable juice,bottled beer,dental care, beef,citrus fruit,tropical fruit,whole milk,butter milk,frozen vegetables,rolls/buns,brown bread,pickled vegetables
# Top 5 recommendations for dental care,male cosmetics: pip fruit,whole milk,butter,cream cheese ,bottled water,newspapers, spread cheese,rolls/buns,white bread,pet care,fruit/vegetable juice,newspapers, pip fruit,brown bread,misc. beverages,chewing gum, frankfurter,meat,tropical fruit,onions,oil,baking powder,tea,cling film/bags, citrus fruit,curd,yogurt,sliced cheese,rolls/buns,oil,bottled water
# Top 5 recommendations for sausage,turkey,beef,citrus fruit,herbs,flour,margarine,Instant food products,bottled water: ham,beef,other vegetables,whole milk,domestic eggs,oil,sugar,jam,bottled water,pot plants, herbs,bottled water, chicken,pip fruit,other vegetables,whole milk,dessert,yogurt,whipped/sour cream,rolls/buns,pasta,soda,waffles, frankfurter,sausage,root vegetables,other vegetables,rolls/buns,oil,pickled vegetables,bottled beer,chewing gum,dishes, sausage,other vegetables,rolls/buns,baking powder,soda,cling film/bags,house keeping products
# Top 5 recommendations for whole milk,pastry,soda: onions,other vegetables,rolls/buns,salt,chocolate,specialty bar,shopping bags, meat,frozen vegetables,soda, tropical fruit, tropical fruit,berries,other vegetables,whole milk,yogurt,whipped/sour cream,frozen vegetables,coffee,bottled water,soda,salty snack,long life bakery product,specialty bar, sausage,ham,other vegetables
# Top 5 recommendations for beef,tropical fruit,root vegetables,whole milk: brown bread,specialty chocolate,shopping bags, bottled beer,chocolate,specialty bar, citrus fruit,tropical fruit,root vegetables,yogurt,canned vegetables,bottled water,soda,softener, pasta, whole milk,butter,fruit/vegetable juice,candy
# Top 5 recommendations for ham,whole milk,domestic eggs,tea,bottled water,bottled beer: onions,frozen meals, other vegetables,frozen vegetables,frozen fish,rolls/buns,pickled vegetables, onions,other vegetables,specialty cheese,bottled water,shopping bags, whole milk,brown bread,flower (seeds), root vegetables,bottled water,bottled beer
# Top 5 recommendations for finished products,chicken,pork,beef,hamburger meat,berries,butter,domestic eggs,rolls/buns,brown bread,pastry,flour,Instant food products,soda,salty snack,chocolate,specialty chocolate,hygiene articles,flower (seeds): pork,rolls/buns,margarine,canned beer,napkins, UHT-milk, whole milk,white bread,salty snack, beef,other vegetables,whole milk,brown bread,waffles, domestic eggs,white bread,specialty fat,mustard,specialty vegetables
# Top 5 recommendations for dessert,beverages,ice cream,soda: sausage,pork,yogurt,spread cheese,cereals,canned vegetables,salty snack,cling film/bags,shopping bags, root vegetables,other vegetables,canned fish,shopping bags, onions,other vegetables,whole milk,butter,butter milk,whipped/sour cream,ice cream,rolls/buns,bottled beer,long life bakery product,dental care,napkins,newspapers, frankfurter,root vegetables, citrus fruit,herbs,whole milk,bottled water,bottled beer,pot plants
# Top 5 recommendations for rolls/buns,bottled water,bottled beer: whole milk,butter,yogurt,rolls/buns,candles,newspapers, yogurt,rolls/buns,dog food,bottled water,canned beer,shopping bags, pork,butter milk,pickled vegetables,soda,canned beer,liquor, other vegetables,whole milk,mayonnaise,frozen potato products,pastry,margarine,baking powder, citrus fruit,tropical fruit,brown bread,sauces,soda,napkins,shopping bags
# Top 5 recommendations for sausage,liver loaf,misc. beverages,fruit/vegetable juice,canned beer,salty snack,shopping bags: pip fruit,bottled water,white wine,newspapers, other vegetables,newspapers, sausage,white bread,coffee,soda,shopping bags, packaged fruit/vegetables,canned fish, tropical fruit,grapes,oil,canned vegetables,tea,fruit/vegetable juice,snack products
# Top 5 recommendations for citrus fruit,soda,misc. beverages,canned beer,chocolate,specialty chocolate,candy,shopping bags: root vegetables,whipped/sour cream,frozen vegetables,domestic eggs,rolls/buns, butter,margarine, tropical fruit,margarine,rum, pip fruit,whipped/sour cream, sweet spreads,soda,waffles
# Top 5 recommendations for whole milk,curd,margarine: chicken,tropical fruit,other vegetables,shopping bags, yogurt,margarine,bottled water,chewing gum, citrus fruit,tropical fruit,pip fruit,whole milk,yogurt,rolls/buns,pastry,white wine,red/blush wine,hygiene articles, domestic eggs,white bread,pastry,canned beer,newspapers, beef,whole milk,white bread
# Top 5 recommendations for sausage,yogurt,cream: beef,other vegetables,yogurt,beverages,rolls/buns,flour,margarine,cat food,bottled water,fruit/vegetable juice, frankfurter,finished products,chicken,other vegetables,whole milk,curd,flour,pasta,salty snack, other vegetables,sweet spreads,long life bakery product,detergent, ham,bottled water,soda, frankfurter,onions,pickled vegetables
# Top 5 recommendations for root vegetables,whole milk,oil,mustard,fruit/vegetable juice,waffles,dishes,shopping bags: tropical fruit,berries,whipped/sour cream,rolls/buns,pickled vegetables,coffee,soda,long life bakery product, tropical fruit,root vegetables,other vegetables,packaged fruit/vegetables,flower (seeds), pork,root vegetables,other vegetables,whole milk,cream cheese ,coffee,bottled water,bottled beer, sausage,pork,white wine, butter milk,yogurt,salty snack,specialty chocolate
# Top 5 recommendations for organic sausage,rolls/buns: other vegetables,whole milk,butter,yogurt,beverages,sliced cheese,cereals,pot plants, coffee,soda,fruit/vegetable juice,waffles,seasonal products, canned beer,chewing gum, citrus fruit,tropical fruit,pip fruit,berries,bottled water,soda,red/blush wine, rolls/buns,oil,bottled water,chewing gum,chocolate marshmallow,hygiene articles,napkins
# Top 5 recommendations for pork,tropical fruit,other vegetables,coffee,shopping bags: hamburger meat,citrus fruit,tropical fruit,whole milk,yogurt,brown bread,napkins,shopping bags, sausage,ham,other vegetables,whole milk,curd,cream cheese ,processed cheese,frozen potato products,pastry, bottled water,soda,fruit/vegetable juice, meat,whole milk,rolls/buns, chicken,pip fruit,root vegetables,herbs,whole milk,frozen vegetables,domestic eggs
# Top 5 recommendations for dessert,yogurt,rolls/buns,meat spreads,bottled water,soda,chocolate,shopping bags: red/blush wine,newspapers, UHT-milk,brown bread, rolls/buns,vinegar,bottled beer, root vegetables,herbs,other vegetables,candy,seasonal products,shopping bags, bottled water,newspapers
# Top 5 recommendations for citrus fruit,root vegetables,other vegetables,whipped/sour cream,processed cheese,rolls/buns,newspapers: sausage,chicken,pork,beef,citrus fruit,tropical fruit,whole milk,processed cheese,frozen meals,domestic eggs,brown bread,semi-finished bread,soda,chocolate, tropical fruit,root vegetables,other vegetables,packaged fruit/vegetables,flower (seeds), processed cheese,soda, tropical fruit,curd, frankfurter,hamburger meat
# Top 5 recommendations for hamburger meat,root vegetables,frozen vegetables,rolls/buns,brown bread,margarine,soda,fruit/vegetable juice,white wine,kitchen towels,newspapers: cereals,specialty chocolate,pot plants, whole milk,curd,pastry,fruit/vegetable juice,newspapers, ham,whole milk,sliced cheese,spread cheese,brown bread,pickled vegetables,bottled beer,shopping bags, UHT-milk,pastry,waffles, pip fruit,bottled water,soda,fruit/vegetable juice,canned beer,newspapers
# Top 5 recommendations for citrus fruit,tropical fruit,pip fruit,grapes,berries,root vegetables,other vegetables,beverages,Instant food products,long life bakery product: pork,berries,root vegetables,other vegetables,pastry,specialty bar, chicken,bottled beer,red/blush wine,newspapers, other vegetables,whole milk,waffles, finished products,other vegetables,butter,cream cheese ,processed cheese,domestic eggs,rolls/buns,pastry,long life bakery product,candy, sausage,yogurt,rolls/buns,soda
# Top 5 recommendations for rolls/buns,canned fruit: flour,sugar, pork,beef,berries,packaged fruit/vegetables,whole milk,mayonnaise,frozen fish,frozen potato products,oil,mustard,cat food,coffee,soda,chocolate,dish cleaner,napkins,newspapers, whole milk,butter,yogurt,domestic eggs,rolls/buns, tropical fruit,berries,root vegetables,other vegetables,whole milk,cream cheese ,frozen meals,white bread,soda,salty snack,napkins,shopping bags, pip fruit,butter milk,soda
# Top 5 recommendations for ham,other vegetables,condensed milk,domestic eggs,salty snack: butter,white bread, UHT-milk,bottled water,soda, sausage,beverages,rolls/buns,misc. beverages,waffles,shopping bags, pasta,soda,long life bakery product, hamburger meat,other vegetables,rolls/buns
# Top 5 recommendations for whole milk,brown bread,pastry: sausage,pip fruit,other vegetables,yogurt,hard cheese,domestic eggs,rolls/buns,bottled water,newspapers, whole milk,yogurt,sliced cheese,mayonnaise,rolls/buns,pasta,specialty chocolate, meat,beef,onions,white wine,dishes, tropical fruit,grapes,other vegetables,whole milk,brown bread,pastry,fruit/vegetable juice,long life bakery product,pot plants, tropical fruit,whole milk,ice cream,red/blush wine,chocolate,shopping bags
# Top 5 recommendations for frankfurter,sausage,whole milk,margarine,sauces,chocolate: pork,root vegetables,processed cheese,curd cheese,margarine, sausage,ham,citrus fruit,other vegetables,butter,hard cheese,curd cheese,domestic eggs,rolls/buns,brown bread,margarine,soda,candy, yogurt,rolls/buns,pastry,bottled water,soda,shopping bags, frankfurter,tropical fruit,root vegetables,whole milk,butter,curd,yogurt, canned beer,red/blush wine
# ...
# Top 5 recommendations for chicken,berries,root vegetables,other vegetables,whole milk,butter,curd,condensed milk,rolls/buns,white bread,brown bread,oil,baking powder,salty snack,long life bakery product: tropical fruit,pip fruit,whole milk,cream cheese ,frozen vegetables,ice cream,bottled water,shopping bags, pork,citrus fruit,tropical fruit,grapes,root vegetables,cream cheese ,pet care,bottled water,fruit/vegetable juice,bottled beer, meat,beef,citrus fruit,pip fruit,canned beer,chewing gum,shopping bags, sweet spreads,coffee,chocolate,seasonal products, sausage,other vegetables,cream cheese ,domestic eggs,soda
# Top 5 recommendations for pork,hamburger meat,pip fruit,root vegetables,onions,other vegetables,whole milk,dessert,whipped/sour cream,soft cheese,hard cheese,domestic eggs,salt,pasta,cat food,fruit/vegetable juice,kitchen towels: frankfurter,sausage,processed cheese,rolls/buns,liquor, citrus fruit,tropical fruit,prosecco, citrus fruit,grapes,whole milk,pastry,canned fruit,canned fish,chocolate,specialty bar,hygiene articles,napkins,shopping bags, chicken,dessert,yogurt,frozen vegetables,domestic eggs,salt,pasta,specialty fat,bottled water,newspapers, citrus fruit,dessert,photo/film
# Top 5 recommendations for frankfurter,sausage,butter milk,rolls/buns,margarine: sausage,hamburger meat,citrus fruit,whole milk,yogurt,white bread, sausage,citrus fruit,root vegetables,other vegetables,rolls/buns,soda,fruit/vegetable juice,bottled beer,dental care, other vegetables,butter milk,rolls/buns,oil,bottled water,fruit/vegetable juice,softener,dishes, tropical fruit,other vegetables,whole milk,curd,frozen dessert,rolls/buns,margarine,jam, root vegetables,other vegetables,whole milk,sliced cheese,frozen vegetables,frozen fish,frozen dessert,chocolate
# Top 5 recommendations for pip fruit,whole milk,pastry,hygiene articles,napkins: meat,hamburger meat,whole milk,UHT-milk,hard cheese,pastry,sugar,pickled vegetables,long life bakery product, other vegetables,soft cheese, sausage,chicken,other vegetables,whole milk,whipped/sour cream,hard cheese,frozen meals,rolls/buns,cereals,coffee,nut snack,cake bar,cleaner,skin care,female sanitary products,house keeping products, beef,yogurt,white bread,flour,soda,fruit/vegetable juice,bottled beer,brandy,cooking chocolate, other vegetables,butter milk,yogurt,fruit/vegetable juice
# Top 5 recommendations for chicken,pork,coffee,canned beer: pastry,newspapers, whole milk,white bread, pastry,waffles,shopping bags, pip fruit,coffee, pork,root vegetables,other vegetables,beverages,rolls/buns,pastry,sauces,bottled water,soda,red/blush wine,sparkling wine,chocolate,specialty chocolate,candy,napkins,newspapers
# Top 5 recommendations for ham,hamburger meat,pip fruit,butter,butter milk,yogurt,frozen meals,rolls/buns,semi-finished bread,pasta,sweet spreads,waffles,softener,shopping bags: specialty chocolate,pot plants, dessert,beverages, ice cream,bottled beer,prosecco,dishes,shopping bags, tropical fruit,dessert,yogurt,UHT-milk,domestic eggs,rolls/buns,brown bread,canned vegetables,meat spreads,cake bar,chocolate,specialty chocolate, whipped/sour cream,margarine,long life bakery product
# Top 5 recommendations for beverages,pastry,newspapers: frankfurter,beef,root vegetables,butter milk,chocolate, tropical fruit,root vegetables,whole milk,curd,dessert,butter milk,yogurt,sauces,bottled water,syrup,specialty chocolate,cleaner, root vegetables,other vegetables,whole milk,specialty bar,dishes, citrus fruit,other vegetables,canned fish,bottled water, dessert,soft cheese,brown bread,pastry,soda,long life bakery product,hygiene articles,shopping bags
# Top 5 recommendations for margarine,sugar,bottled water,fruit/vegetable juice,newspapers: ice cream,sugar,flower (seeds), pip fruit,whole milk,domestic eggs,sweet spreads,soda, bottled water,shopping bags, pip fruit,butter,yogurt, beef,whole milk,oil,canned beer,salty snack
# Top 5 recommendations for pork,other vegetables,chewing gum,napkins,dishes: ham,bottled water,soda, frozen dessert,bottled water, curd,cake bar, other vegetables,canned beer,shopping bags, frankfurter,beef,tropical fruit,root vegetables,packaged fruit/vegetables,whole milk,frozen vegetables
# Top 5 recommendations for ham,other vegetables,whole milk,whipped/sour cream,brown bread,oil,sugar,hygiene articles: other vegetables,whole milk,meat spreads,cake bar,chocolate,shopping bags, pork,other vegetables,whole milk,brown bread,pastry,soda,misc. beverages, tropical fruit, beef,citrus fruit,root vegetables,specialty chocolate, ham,whole milk,sliced cheese,bottled water,napkins
# Top 5 recommendations for berries,curd,yogurt,whipped/sour cream,rolls/buns,soda,female sanitary products: beverages,rolls/buns,soda,misc. beverages,liqueur,cake bar, sausage,citrus fruit,tropical fruit,other vegetables,tidbits,shopping bags, herbs,whole milk,butter,soups,bottled water,bottled beer, liver loaf,citrus fruit,other vegetables,curd,salad dressing,semi-finished bread,abrasive cleaner, meat,beef,citrus fruit,pip fruit,canned beer,chewing gum,shopping bags
# Top 5 recommendations for tropical fruit,whole milk,curd,yogurt,sliced cheese,mayonnaise,frozen meals,pastry,soda: herbs,pot plants, condensed milk,rolls/buns,sugar,cat food, dessert,cream cheese ,waffles, whisky, chicken,citrus fruit,root vegetables,other vegetables,whole milk,yogurt,hard cheese,processed cheese,mayonnaise,frozen vegetables,pastry,roll products ,rice,margarine,sugar,pickled vegetables,bottled water,fruit/vegetable juice,candy,skin care,napkins
# Top 5 recommendations for tropical fruit,nuts/prunes,other vegetables,whole milk,dessert,sliced cheese,soda,bottled beer,napkins: whole milk,butter,yogurt,rolls/buns,coffee,fruit/vegetable juice,detergent, sausage,tropical fruit,whole milk,processed cheese,frozen vegetables,domestic eggs,rolls/buns,white bread,rice,soda,detergent,softener,decalcifier,napkins,shopping bags, chicken,beef,other vegetables, whipped/sour cream,pastry,specialty bar, other vegetables,rolls/buns
# Top 5 recommendations for dessert,white bread,margarine,sugar,chocolate: citrus fruit,packaged fruit/vegetables,yogurt,bottled water, dish cleaner,bathroom cleaner,hygiene articles,napkins, beef,other vegetables,margarine,candles, meat,bottled beer,shopping bags, frozen dessert,bottled water
# Top 5 recommendations for whole milk,curd,bottled water: whole milk,frozen meals,mustard,canned fish,bottled beer, dessert,rolls/buns,soda, soda,candy, sauces,softener, berries,herbs,pot plants
# Top 5 recommendations for sliced cheese,frozen meals,margarine,red/blush wine: fruit/vegetable juice,waffles, other vegetables,whole milk,soda,chocolate, salt,margarine,canned beer, citrus fruit,tropical fruit,whole milk,butter milk,rice,oil,canned fruit,bottled water,white wine,popcorn,hygiene articles,shopping bags, sugar,bottled water,white wine
# Top 5 recommendations for beef,root vegetables,other vegetables,frozen vegetables,frozen dessert,domestic eggs: frankfurter,cream cheese ,white bread, domestic eggs,misc. beverages, frankfurter,tropical fruit,pip fruit,sliced cheese,mayonnaise,domestic eggs,rolls/buns,fruit/vegetable juice,shopping bags, chicken,other vegetables,salt, ham,chicken,pork,root vegetables,whole milk,whipped/sour cream,rolls/buns,sugar,soda,waffles,chocolate,specialty chocolate,chocolate marshmallow,napkins
# Top 5 recommendations for meat,hamburger meat,Instant food products,soda: tropical fruit,other vegetables,white bread,bottled water,chocolate, beef,whole milk,butter,rolls/buns,pastry,cat food,hygiene articles, sausage,beef,citrus fruit,yogurt,brown bread,margarine,soda,long life bakery product,hygiene articles,napkins,pot plants, pastry,soda,canned beer,white wine,newspapers, specialty chocolate,newspapers
# Top 5 recommendations for citrus fruit,berries,other vegetables,whole milk,frozen meals,newspapers: whipped/sour cream, beverages, frozen vegetables,frozen meals,shopping bags, sausage,soft cheese,mayonnaise,ice cream, rolls/buns,canned fish,canned beer,waffles,newspapers
# Top 5 recommendations for tropical fruit,pip fruit,rolls/buns,pastry,bottled water,fruit/vegetable juice,newspapers: margarine,pickled vegetables,coffee,bottled beer,chocolate marshmallow, pip fruit,root vegetables,other vegetables,whole milk,margarine,bottled water, butter,brown bread,bottled beer,white wine,shopping bags, pork,root vegetables,other vegetables,mayonnaise,domestic eggs,rolls/buns,mustard,fruit/vegetable juice,chewing gum,dishes, soda,fruit/vegetable juice,long life bakery product
# Top 5 recommendations for sausage,whole milk,sliced cheese,pastry: other vegetables,condensed milk,soda,newspapers, rolls/buns,brown bread,soda,misc. beverages,bottled beer, tropical fruit,misc. beverages, curd,seasonal products,female sanitary products, frozen meals,frozen fish,chocolate
# Top 5 recommendations for whole milk,yogurt,frozen meals,bottled water: tropical fruit,bottled water, yogurt,rolls/buns,chewing gum, citrus fruit,herbs,whole milk,bottled water,bottled beer,pot plants, sausage,beef,tropical fruit,onions,frozen vegetables,domestic eggs,white bread,semi-finished bread,sugar,baking powder,canned fish,coffee,seasonal products, root vegetables,other vegetables,packaged fruit/vegetables,rolls/buns,canned beer,red/blush wine
# Top 5 recommendations for sausage,citrus fruit,root vegetables: yogurt,newspapers, fruit/vegetable juice,nut snack, sausage,meat,tropical fruit,pip fruit,pastry,sugar,coffee,candles,pot plants, grapes,other vegetables,butter,newspapers, chicken,pork,beef,berries,sliced cheese,jam,shopping bags
# Top 5 recommendations for sausage,other vegetables,whole milk,dessert,butter milk,yogurt,whipped/sour cream,brown bread,bottled water,soda,long life bakery product,cake bar: sausage,liver loaf,misc. beverages,fruit/vegetable juice,canned beer,salty snack,shopping bags, tropical fruit,berries,onions,butter,yogurt,coffee,soda,fruit/vegetable juice,specialty bar, whipped/sour cream,specialty bar, citrus fruit,yogurt,hygiene articles, frankfurter,tropical fruit,pip fruit,other vegetables,frozen vegetables,frozen fish,zwieback,margarine
# Top 5 recommendations for whole milk,curd,yogurt,whipped/sour cream,rolls/buns,coffee,bottled water,waffles,newspapers: whole milk,baking powder,waffles,cleaner,newspapers, other vegetables,whole milk,yogurt,spices, tropical fruit,pip fruit,grapes,ice cream,frozen potato products,rolls/buns,pastry,soda,misc. beverages,salty snack,long life bakery product,chewing gum,specialty bar,napkins,photo/film, pastry,salty snack, dessert,frozen potato products,specialty chocolate
# Top 5 recommendations for beef,citrus fruit,cream cheese ,frozen fish,flour,margarine,sugar,baking powder,salty snack,chewing gum: root vegetables,other vegetables,whole milk,soups,bottled beer, butter,white bread, soda,detergent, other vegetables,butter milk,frozen meals,ice cream,pastry, tropical fruit,berries,rolls/buns,pastry,margarine,coffee,shopping bags
# Top 5 recommendations for pip fruit,grapes,berries,other vegetables,whole milk,UHT-milk,rolls/buns,zwieback,bottled water,soda,red/blush wine,specialty bar: citrus fruit,tropical fruit,yogurt,rolls/buns,red/blush wine, tropical fruit,root vegetables,whole milk,whipped/sour cream,domestic eggs, other vegetables,chocolate, butter,sliced cheese,brown bread, frankfurter,white bread,margarine,shopping bags
# Top 5 recommendations for pork,frozen vegetables,pastry: hamburger meat,packaged fruit/vegetables,whole milk,curd,yogurt,pastry, tropical fruit,pip fruit,frozen meals,softener, ham,tropical fruit,specialty cheese,long life bakery product,hygiene articles,newspapers, frankfurter,sausage,processed cheese,rolls/buns,liquor, beef,yogurt,white bread,flour,soda,fruit/vegetable juice,bottled beer,brandy,cooking chocolate
# Top 5 recommendations for ice cream,long life bakery product,specialty chocolate,specialty bar: fish,cream cheese ,coffee, root vegetables,margarine,candles, frankfurter,whole milk,yogurt,frozen fish,domestic eggs, frozen dessert,semi-finished bread, frankfurter,sausage,root vegetables,yogurt,whipped/sour cream,pastry,napkins
# Top 5 recommendations for chicken,hamburger meat,citrus fruit,root vegetables,other vegetables,cream cheese ,curd cheese,domestic eggs,cat food,long life bakery product: beef,grapes,other vegetables,whole milk,dessert,yogurt,frozen vegetables,cake bar,dishes,newspapers, citrus fruit,butter,cream cheese ,white bread,oil,margarine,newspapers, frankfurter,hamburger meat,root vegetables,whole milk,yogurt,brown bread,chocolate, pork,whole milk,dessert, other vegetables,whipped/sour cream,condensed milk,salt
# Top 5 recommendations for citrus fruit,herbs,other vegetables,dessert,sugar,shopping bags: sausage,pork,grapes,whole milk,rolls/buns,pastry,soda,specialty bar,bathroom cleaner, semi-finished bread, chicken,onions,herbs,hygiene articles, dish cleaner, ham,tropical fruit
# Top 5 recommendations for frankfurter,tropical fruit,other vegetables,whole milk,frozen meals,rolls/buns,detergent,napkins,newspapers: pip fruit,soft cheese, curd,rolls/buns,pastry, semi-finished bread, whole milk,curd,yogurt,chocolate marshmallow,candy,newspapers, frankfurter,pork,citrus fruit,pip fruit,other vegetables,whipped/sour cream,UHT-milk,salad dressing,frozen potato products,salty snack,newspapers
# Top 5 recommendations for sausage,butter,rolls/buns,pickled vegetables,soda,fruit/vegetable juice,waffles: meat,pork,soft cheese,oil,margarine,seasonal products, spread cheese,soda, sliced cheese,rolls/buns,margarine,soda,shopping bags, brown bread,sauces,pet care, other vegetables
# Top 5 recommendations for tropical fruit,other vegetables,domestic eggs,zwieback,ketchup,soda,dishes: sausage,whole milk,yogurt,UHT-milk,rolls/buns, sausage,bottled water, citrus fruit,domestic eggs,jam, pork,other vegetables,whole milk,cream cheese ,frozen fish,rolls/buns,pastry, chicken,pork,frozen vegetables,frozen meals,rolls/buns,soda,long life bakery product
# Top 5 recommendations for sausage,chicken,beef,hamburger meat,citrus fruit,grapes,root vegetables,whole milk,butter,whipped/sour cream,flour,coffee,red/blush wine,salty snack,chocolate,hygiene articles,napkins: grapes, sausage,other vegetables,whole milk,rolls/buns,soups,cake bar,shopping bags, hamburger meat,other vegetables,pickled vegetables, flower (seeds), rolls/buns,waffles
# Top 5 recommendations for chicken,citrus fruit,other vegetables,butter,yogurt,frozen dessert,domestic eggs,rolls/buns,rum,cling film/bags: ham,pork,hamburger meat,pip fruit,other vegetables,whole milk,butter,curd,dessert,butter milk,whipped/sour cream,domestic eggs,brown bread,roll products ,hygiene articles, frankfurter,sausage,chicken,citrus fruit,root vegetables,herbs,packaged fruit/vegetables,whole milk,salt,sugar,bottled beer,napkins, whole milk,yogurt,pastry,soda,misc. beverages,shopping bags, onions,whole milk,bottled beer,liquor (appetizer),detergent,dishes, frozen potato products,rolls/buns,brown bread
# Top 5 recommendations for semi-finished bread,bottled water,soda,bottled beer: tropical fruit,root vegetables,whole milk,curd,dessert,butter milk,yogurt,sauces,bottled water,syrup,specialty chocolate,cleaner, pet care,bottled water,misc. beverages,shopping bags, rolls/buns,fruit/vegetable juice,long life bakery product,newspapers, butter milk,tea,fruit/vegetable juice,bottled beer,red/blush wine,shopping bags, hamburger meat,mustard,soups,Instant food products,sweet spreads,soda,newspapers
# Top 5 recommendations for chicken,tropical fruit,other vegetables,vinegar,shopping bags: pip fruit,whole milk,curd,whipped/sour cream,salt, pork,citrus fruit,other vegetables,yogurt, yogurt,rolls/buns,vinegar,margarine,sparkling wine, sausage,ham,tropical fruit,pip fruit,other vegetables,whole milk,curd,dessert,condensed milk,white bread,fruit/vegetable juice, soups,soda,shopping bags

# %% [markdown]
# # involves defining a function `evaluate_recommendations` that takes an input item and returns the top k recommended items based on similarity scores.
#
# Here is the implementation of the function:

# %%
def evaluate_recommendations(input_item, top_k=5):
    # Convert the input item to its integer id
    input_item_id = item_to_int[input_item]

    # Get the item embeddings
    item_embeddings = model.item_embedding.weight.data.cpu().numpy()

    # Compute the similarity between items
    similarity_scores = np.dot(item_embeddings[input_item_id], item_embeddings.T)

    # Get the top k recommendations
    top_k_indices = np.argsort(similarity_scores)[-top_k:]

    # Convert the integer ids back to item names
    int_to_item = {v: k for k, v in item_to_int.items()}
    top_k_items = [int_to_item[i] for i in top_k_indices[::-1]]

    # Print the top k recommendations for the input item
    print(f"Top {top_k} recommendations for {input_item}: {', '.join(top_k_items)}")

# %% [markdown]
# This function takes two parameters:
#
# * `input_item`: the name of the item for which recommendations are to be generated.
# * `top_k` (default 5): the number of top recommendations to be generated.
#
# The function first converts the input item name to its integer id using the `item_to_int` dictionary. It then retrieves the item embeddings from the trained model and computes the similarity scores between the input item and all other items using the dot product of the input item's embedding and the embedding of all other items.
#
# Next, it retrieves the top k indices of items with the highest similarity scores and converts these integer ids back to item names using the `int_to_item` dictionary. Finally, it prints the top k recommended items for the input item.
#
# Here is an example usage of the function:

# %%
evaluate_recommendations('chicken')
# Out:
# Top 5 recommendations for chicken: chicken, beef,other vegetables,whole milk,rolls/buns, beef,citrus fruit,root vegetables,specialty chocolate, citrus fruit,tropical fruit,whole milk,yogurt, meat,yogurt
